# %%
# !python --version
# Out:
# Python 3.6.9

# %%
# !pip install numpy==1.17
# !pip install scipy==1.1
# Out:
# Requirement already satisfied: numpy==1.17 in /usr/local/lib/python3.6/dist-packages (1.17.0)
# Requirement already satisfied: scipy==1.1 in /usr/local/lib/python3.6/dist-packages (1.1.0)
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.1) (1.17.0)

# %%
# !pip install nipy
# Out:
# Requirement already satisfied: nipy in /usr/local/lib/python3.6/dist-packages (0.4.2)
# Requirement already satisfied: sympy>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from nipy) (1.1.1)
# Requirement already satisfied: nibabel>=1.2 in /usr/local/lib/python3.6/dist-packages (from nipy) (3.0.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.6/dist-packages (from sympy>=0.7.0->nipy) (1.1.0)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.6/dist-packages (from nibabel>=1.2->nipy) (1.17.0)

# %%
# !pip install bdpy
# Out:
# Requirement already satisfied: bdpy in /usr/local/lib/python3.6/dist-packages (0.14rc6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from bdpy) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from bdpy) (1.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from bdpy) (1.17.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from bdpy) (2.10.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->bdpy) (0.15.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->bdpy) (1.12.0)

# %%
import numpy
numpy.__version__
# Out:
# '1.17.0'

# %%
import scipy
scipy.__version__
# Out:
# '1.1.0'

# %%
import nipy
from nipy.modalities.fmri.glm import GeneralLinearModel
from nipy.modalities.fmri.design_matrix import make_dmtx

# %%
import bdpy
